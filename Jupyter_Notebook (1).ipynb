# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lucia de Fang Ma Li**
#
# Project Assistant

# %% [markdown]
# *I am interested in data science because there are many possibilities to create solutions to current and future problems.*

# %% [markdown]
# ### This code will calculate 2+2

# %%
2+2
# Out:
# 4

# %% [markdown]
# > Hi
# >> Hi
# >>> Bye
#
# 1. 3
# 2. 2
# 3. 1
#
# ![450_1000.jpg](attachment:39cbd748-47a0-470d-8729-e5a16854d84c.jpg)
#
# `Error 404`
#
# | First name | Last name |
# | ----------- | ----------- |
# | Ia | Mann |
# | Tim | Ado |
#
# ---
#
# ~~Dooooooon't~~
